# %%
'''
|-----------------------------------------------------------------------|
| Criando servico de SparkStreaming com Java                            |
| Código pode ser executado em VM de testes da Databricks               |
| https://community.cloud.databricks.com/                               |
|-----------------------------------------------------------------------|
'''
from pyspark.sql import SparkSession

spark_session = SparkSession.builder.enableHiveSupport().getOrCreate()
# Duas maneiras de acessar o contexto do spark a partir da sessão do spark
spark_context = spark_session._sc
spark_context = spark_session.sparkContext
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark_context
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: </div>
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=3015855169488555#setting/sparkui/0824-212149-bang966/driver-3547358618965630738">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
'''
|----------------------------------------------------------|
| Utilizando SparkStreming para escuta e recepção de dados |
|----------------------------------------------------------|
'''
from pyspark.streaming import StreamingContext

# cria contexto Spark para trabalhar com streaming de dados
ssc = StreamingContext(sc, 1)

# cria dataframe 'lines' para receber streaming de dados da porta 9999 da máquina local
lines = ssc.socketTextStream('localhost', 9999)

# cria funções lambda para replicar o timestamp a cada 1 segundo
counts = lines.flatMap(lambda line: line.split(" ")).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a+b)
counts.pprint()

# inicia serviço
ssc.start()
# coloca serviço em standby sem previsão de término
ssc.awaitTermination()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-------------------------------------------
# Time: 2021-08-24 21:34:34
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-08-24 21:34:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-08-24 21:34:36
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-08-24 21:34:37
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-08-24 21:34:38
# -------------------------------------------
#
# ...
